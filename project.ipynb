# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
test = pd.read_csv('Kurs_project_task/test.csv')
train = pd.read_csv('Kurs_project_task/train.csv')

# %%
train.head(10)
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
# 5  12915          59    3.0  80.384479   46.683720           12.0      5
# 6  14549         154    2.0  62.254114   37.160377            7.0      3
# 7  11993          74    2.0  80.312926         NaN            0.0     14
# 8   5172           1    2.0  64.511437         NaN            1.0      9
# 9   8649          23    1.0  46.461409   18.915552            8.0     13
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040         B         B        33      7976
# ...

# %%
train.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %%
train.dtypes
# Out:
# Id                 int64
# DistrictId         int64
# Rooms            float64
# Square           float64
# LifeSquare       float64
# KitchenSquare    float64
# Floor              int64
# HouseFloor       float64
# HouseYear          int64
# Ecology_1        float64
# Ecology_2         object
# Ecology_3         object
# Social_1           int64
# Social_2           int64
# Social_3           int64
# Healthcare_1     float64
# Helthcare_2        int64
# Shops_1            int64
# Shops_2           object
# Price            float64
# dtype: object

# %%
train.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
train.columns
# Out:
# Index(['Id', 'DistrictId', 'Rooms', 'Square', 'LifeSquare', 'KitchenSquare',
#        'Floor', 'HouseFloor', 'HouseYear', 'Ecology_1', 'Ecology_2',
#        'Ecology_3', 'Social_1', 'Social_2', 'Social_3', 'Healthcare_1',
#        'Helthcare_2', 'Shops_1', 'Shops_2', 'Price'],
#       dtype='object')

# %%
train['Id'].unique().shape
# Out:
# (10000,)

# %%
train.shape
# Out:
# (10000, 20)

# %%
sns.distplot(train['Id']);

# %%
sns.pairplot(data=train)

# %%
train.corr()
# Out:
#                      Id  DistrictId     Rooms    Square  LifeSquare  \
# Id             1.000000    0.012973 -0.005847 -0.010071    0.018449
# DistrictId     0.012973    1.000000  0.071432 -0.026613   -0.019910
# Rooms         -0.005847    0.071432  1.000000  0.662893    0.131336
# Square        -0.010071   -0.026613  0.662893  1.000000    0.196129
# LifeSquare     0.018449   -0.019910  0.131336  0.196129    1.000000
# KitchenSquare  0.019880    0.040358  0.005123  0.008320   -0.001195
# Floor          0.001348   -0.120373 -0.000665  0.114791    0.024559
# HouseFloor    -0.008376   -0.149051 -0.029302  0.081505    0.027442
# HouseYear      0.005004    0.013430 -0.010612 -0.009032   -0.002210
# Ecology_1      0.018097    0.065294 -0.032347 -0.064479   -0.023629
# Social_1      -0.000772    0.246463  0.075980 -0.070690   -0.048363
# Social_2      -0.002033    0.167479  0.071335 -0.043120   -0.039283
# Social_3      -0.009358    0.136095  0.012811  0.035241    0.012763
# ...

# %%
sns.heatmap(train.corr());

# %%
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(train.corr());

# %%
train.sort_values('Id')
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 7885      0           0    1.0  109.144492   84.613939           15.0      6
# 5549      2           2    1.0   34.472263   16.069376            5.0      5
# 4808      5           5    3.0   57.607965   38.955672            5.0      3
# 4447      6           6    1.0   42.466813   40.010160            1.0     14
# 2684     10           6    3.0   75.888156   78.324716            1.0     11
# ...     ...         ...    ...         ...         ...            ...    ...
# 2937  16793          53    1.0   33.258974   19.576423            6.0      6
# 2457  16794          29    2.0   45.280336   32.370920            5.0      8
# 659   16796          46    1.0   33.013935   22.277019            6.0      4
# 4768  16797          94    3.0   77.325275   48.101669           10.0      7
# 705   16798          22    1.0   39.956966   19.874715            8.0      2
#
# ...

# %%
sns.boxplot(data=train['Id'], palette='rainbow', orient='h');

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  int64
#  1   DistrictId     10000 non-null  int64
#  2   Rooms          10000 non-null  float64
#  3   Square         10000 non-null  float64
#  4   LifeSquare     7887 non-null   float64
#  5   KitchenSquare  10000 non-null  float64
#  6   Floor          10000 non-null  int64
#  7   HouseFloor     10000 non-null  float64
#  8   HouseYear      10000 non-null  int64
#  9   Ecology_1      10000 non-null  float64
#  10  Ecology_2      10000 non-null  object
#  11  Ecology_3      10000 non-null  object
#  12  Social_1       10000 non-null  int64
#  13  Social_2       10000 non-null  int64
#  14  Social_3       10000 non-null  int64
#  15  Healthcare_1   5202 non-null   float64
#  16  Helthcare_2    10000 non-null  int64
# ...

# %%
train.corr()['Price'].sort_values()
# Out:
# Ecology_1       -0.058381
# HouseYear        0.004305
# Id               0.009880
# KitchenSquare    0.028864
# Social_3         0.074878
# LifeSquare       0.081292
# HouseFloor       0.088280
# Floor            0.128715
# Healthcare_1     0.138755
# Shops_1          0.180876
# Social_2         0.239226
# Helthcare_2      0.253090
# Social_1         0.263286
# DistrictId       0.265100
# Square           0.520075
# Rooms            0.550291
# Price            1.000000
# Name: Price, dtype: float64

# %%
sns.boxplot(train['DistrictId']);

# %%
train.select_dtypes(include='object')
# Out:
#      Ecology_2 Ecology_3 Shops_2
# 0            B         B       B
# 1            B         B       B
# 2            B         B       B
# 3            B         B       B
# 4            B         B       B
# ...        ...       ...     ...
# 9995         B         B       B
# 9996         B         B       A
# 9997         B         B       A
# 9998         B         A       B
# 9999         B         B       B
#
# [10000 rows x 3 columns]

# %%
train['Ecology_2'].unique()
# Out:
# array(['B', 'A'], dtype=object)

# %%
train['Ecology_2'].value_counts()
# Out:
# B    9903
# A      97
# Name: Ecology_2, dtype: int64

# %%
train = pd.get_dummies(train, columns=['Ecology_2'])

# %%
train.columns
# Out:
# Index(['Id', 'DistrictId', 'Rooms', 'Square', 'LifeSquare', 'KitchenSquare',
#        'Floor', 'HouseFloor', 'HouseYear', 'Ecology_1', 'Ecology_3',
#        'Social_1', 'Social_2', 'Social_3', 'Healthcare_1', 'Helthcare_2',
#        'Shops_1', 'Shops_2', 'Price', 'Ecology_2_A', 'Ecology_2_B'],
#       dtype='object')

# %%
train = pd.get_dummies(train, columns=['Ecology_3'])

# %%
train = pd.get_dummies(train, columns=['Shops_2'])

# %%
train.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1  ...  Healthcare_1  Helthcare_2  Shops_1  \
# 0         9.0       1969   0.089040  ...           NaN            0       11
# 1         9.0       1978   0.000070  ...         240.0            1       16
# 2        12.0       1968   0.049637  ...         229.0            1        3
# 3        17.0       1977   0.437885  ...        1084.0            0        5
# 4        12.0       1976   0.012339  ...        2078.0            2        4
#
# ...

# %%
train.columns
# Out:
# Index(['Id', 'DistrictId', 'Rooms', 'Square', 'LifeSquare', 'KitchenSquare',
#        'Floor', 'HouseFloor', 'HouseYear', 'Ecology_1', 'Social_1', 'Social_2',
#        'Social_3', 'Healthcare_1', 'Helthcare_2', 'Shops_1', 'Price',
#        'Ecology_2_A', 'Ecology_2_B', 'Ecology_3_A', 'Ecology_3_B', 'Shops_2_A',
#        'Shops_2_B'],
#       dtype='object')

# %%
train.to_csv('First_blood.csv')

# %%
train_2 = pd.read_csv('First_blood.csv')
train_2.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'DistrictId', 'Rooms', 'Square', 'LifeSquare',
#        'KitchenSquare', 'Floor', 'HouseFloor', 'HouseYear', 'Ecology_1',
#        'Social_1', 'Social_2', 'Social_3', 'Healthcare_1', 'Helthcare_2',
#        'Shops_1', 'Price', 'Ecology_2_A', 'Ecology_2_B', 'Ecology_3_A',
#        'Ecology_3_B', 'Shops_2_A', 'Shops_2_B'],
#       dtype='object')

# %%
train_2.select_dtypes(include=['int', 'float']).head()
# Out:
#    Unnamed: 0     Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  \
# 0           0  14038          35    2.0  47.981561   29.442751            6.0
# 1           1  15053          41    3.0  65.683640   40.049543            8.0
# 2           2   4765          53    2.0  44.947953   29.197612            0.0
# 3           3   5809          58    2.0  53.352981   52.731512            9.0
# 4           4  10783          99    1.0  39.649192   23.776169            7.0
#
#    Floor  HouseFloor  HouseYear  ...  Healthcare_1  Healthcare_2  Shops_1  \
# 0      7         9.0       1969  ...           NaN             0       11
# 1      7         9.0       1978  ...         240.0             1       16
# 2      8        12.0       1968  ...         229.0             1        3
# 3      8        17.0       1977  ...        1084.0             0        5
# 4     11        12.0       1976  ...        2078.0             2        4
#
# ...

# %%
train_2.isnull().sum()
# Out:
# Unnamed: 0          0
# Id                  0
# DistrictId          0
# Rooms               0
# Square              0
# LifeSquare       2113
# KitchenSquare       0
# Floor               0
# HouseFloor          0
# HouseYear           0
# Ecology_1           0
# Social_1            0
# Social_2            0
# Social_3            0
# Healthcare_1     4798
# Healthcare_2        0
# Shops_1             0
# Price               0
# Ecology_2_A         0
# Ecology_2_B         0
# Ecology_3_A         0
# Ecology_3_B         0
# Shops_2_A           0
# Shops_2_B           0
# dtype: int64

# %%
train_2.rename(columns={"Helthcare_2": "Healthcare_2"}, inplace=True)
train_2.head()
# Out:
#    Unnamed: 0     Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  \
# 0           0  14038          35    2.0  47.981561   29.442751            6.0
# 1           1  15053          41    3.0  65.683640   40.049543            8.0
# 2           2   4765          53    2.0  44.947953   29.197612            0.0
# 3           3   5809          58    2.0  53.352981   52.731512            9.0
# 4           4  10783          99    1.0  39.649192   23.776169            7.0
#
#    Floor  HouseFloor  HouseYear  ...  Healthcare_1  Healthcare_2  Shops_1  \
# 0      7         9.0       1969  ...           NaN             0       11
# 1      7         9.0       1978  ...         240.0             1       16
# 2      8        12.0       1968  ...         229.0             1        3
# 3      8        17.0       1977  ...        1084.0             0        5
# 4     11        12.0       1976  ...        2078.0             2        4
#
# ...

# %%
train_2.set_index('Id', inplace=True)
train_2.columns
# Out:
# Index(['Unnamed: 0', 'DistrictId', 'Rooms', 'Square', 'LifeSquare',
#        'KitchenSquare', 'Floor', 'HouseFloor', 'HouseYear', 'Ecology_1',
#        'Social_1', 'Social_2', 'Social_3', 'Healthcare_1', 'Healthcare_2',
#        'Shops_1', 'Price', 'Ecology_2_A', 'Ecology_2_B', 'Ecology_3_A',
#        'Ecology_3_B', 'Shops_2_A', 'Shops_2_B'],
#       dtype='object')

# %%
train_2.drop('Unnamed: 0', inplace=True, axis=1)
train_2.sort_values('Id').head()
# Out:
#     DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# Id
# 0            0    1.0  109.144492   84.613939           15.0      6
# 2            2    1.0   34.472263   16.069376            5.0      5
# 5            5    3.0   57.607965   38.955672            5.0      3
# 6            6    1.0   42.466813   40.010160            1.0     14
# 10           6    3.0   75.888156   78.324716            1.0     11
#
#     HouseFloor  HouseYear  Ecology_1  Social_1  ...  Healthcare_1  \
# Id                                              ...
# 0         15.0       2011   0.319809        25  ...        2857.0
# 2         18.0       1969   0.000000        33  ...           NaN
# 5          9.0       1974   0.150818        16  ...        2643.0
# 6         17.0       2014   0.243205         5  ...         540.0
# 10        17.0       2014   0.243205         5  ...         540.0
#
#     Healthcare_2  Shops_1          Price  Ecology_2_A  Ecology_2_B  \
# Id
# ...

# %%
train_2 = train_2.sort_values('Id')

# %%
train_2.head()
# Out:
#     DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# Id
# 0            0    1.0  109.144492   84.613939           15.0      6
# 2            2    1.0   34.472263   16.069376            5.0      5
# 5            5    3.0   57.607965   38.955672            5.0      3
# 6            6    1.0   42.466813   40.010160            1.0     14
# 10           6    3.0   75.888156   78.324716            1.0     11
#
#     HouseFloor  HouseYear  Ecology_1  Social_1  ...  Healthcare_1  \
# Id                                              ...
# 0         15.0       2011   0.319809        25  ...        2857.0
# 2         18.0       1969   0.000000        33  ...           NaN
# 5          9.0       1974   0.150818        16  ...        2643.0
# 6         17.0       2014   0.243205         5  ...         540.0
# 10        17.0       2014   0.243205         5  ...         540.0
#
#     Healthcare_2  Shops_1          Price  Ecology_2_A  Ecology_2_B  \
# Id
# ...

# %%
import gc

# %%
train_2['DistrictId'].unique()
# Out:
# array([  0,   2,   5,   6,   9,  12,  13,  16,   1,  17,  18,  19,  20,
#         22,  25,  26,   7,  28,  29,  30,  31,  32,   4,  35,  36,  27,
#         38,  40,  41,  43,  44,  11,  46,  47,  49,  34,  50,  52,  54,
#         39,  57,  58,  56,  23,  15,  60,  61,   8,  62,  65,  66,  68,
#         71,  72,  76,  74,  33,  78,  82,  83,  84,  85,  86,  55,  42,
#         87,  88,  89,  67,  90,  21,  93,  81,  53,  94,  97, 101,  45,
#         37, 102,  64, 103, 104,  10, 100, 105,  48,  95, 106, 107,  75,
#         63, 109, 110, 108,  70,   3, 116,  99, 117,  14, 121, 122, 119,
#        125, 127,  59, 128, 129, 131, 132, 133, 135, 124, 137, 130, 139,
#         73, 134, 140, 113,  77,  96,  24, 126,  92,  69, 111,  91, 120,
#        145, 150, 151, 153, 114, 157, 159, 160, 115, 146, 162, 147, 138,
#        166, 123, 168, 144,  79, 142,  80,  98, 170, 152, 171, 163, 148,
#        136, 178, 161, 179, 181, 183, 176, 167, 154, 180, 169, 184, 185,
# ...

# %%
train_2['Rooms'].value_counts().sort_values()
# Out:
# 19.0       1
# 6.0        1
# 10.0       2
# 0.0        8
# 5.0       18
# 4.0      150
# 3.0     2235
# 1.0     3705
# 2.0     3880
# Name: Rooms, dtype: int64

# %%
train_2['KitchenSquare'].value_counts().sort_values()
# Out:
# 23.0         1
# 96.0         1
# 40.0         1
# 48.0         1
# 73.0         1
# 2014.0       1
# 35.0         1
# 75.0         1
# 63.0         1
# 31.0         1
# 27.0         1
# 84.0         1
# 53.0         1
# 39.0         1
# 36.0         1
# 72.0         1
# 26.0         1
# 62.0         1
# 29.0         1
# 60.0         1
# 78.0         1
# 123.0        1
# 21.0         1
# 42.0         1
# 54.0         1
# 1970.0       1
# 66.0         1
# 37.0         2
# 112.0        2
# 58.0         2
# 43.0         2
# 25.0         2
# 30.0         2
# 32.0         2
# 41.0         2
# 51.0         2
# 22.0         3
# 2.0          4
# 18.0         6
# 19.0        11
# 17.0        12
# 20.0        14
# 16.0        16
# 3.0         22
# 15.0        31
# 4.0         39
# 14.0        51
# 13.0        67
# 11.0       233
# 12.0       249
# 7.0        609
# 0.0        697
# 9.0        843
# 6.0       1038
# 10.0      1075
# 5.0       1169
# 8.0       1306
# 1.0       2460
# ...

# %%
train_2['DistrictId'] = train_2['DistrictId'].astype(str)
train_2.head()
# Out:
#    DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# Id
# 0           0    1.0  109.144492   84.613939           15.0      6
# 2           2    1.0   34.472263   16.069376            5.0      5
# 5           5    3.0   57.607965   38.955672            5.0      3
# 6           6    1.0   42.466813   40.010160            1.0     14
# 10          6    3.0   75.888156   78.324716            1.0     11
#
#     HouseFloor  HouseYear  Ecology_1  Social_1  ...  Healthcare_1  \
# Id                                              ...
# 0         15.0       2011   0.319809        25  ...        2857.0
# 2         18.0       1969   0.000000        33  ...           NaN
# 5          9.0       1974   0.150818        16  ...        2643.0
# 6         17.0       2014   0.243205         5  ...         540.0
# 10        17.0       2014   0.243205         5  ...         540.0
#
#     Healthcare_2  Shops_1          Price  Ecology_2_A  Ecology_2_B  \
# Id
# ...

# %%
train_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 0 to 16798
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DistrictId     10000 non-null  object
#  1   Rooms          10000 non-null  float64
#  2   Square         10000 non-null  float64
#  3   LifeSquare     7887 non-null   float64
#  4   KitchenSquare  10000 non-null  float64
#  5   Floor          10000 non-null  int64
#  6   HouseFloor     10000 non-null  float64
#  7   HouseYear      10000 non-null  int64
#  8   Ecology_1      10000 non-null  float64
#  9   Social_1       10000 non-null  int64
#  10  Social_2       10000 non-null  int64
#  11  Social_3       10000 non-null  int64
#  12  Healthcare_1   5202 non-null   float64
#  13  Healthcare_2   10000 non-null  int64
#  14  Shops_1        10000 non-null  int64
#  15  Price          10000 non-null  float64
#  16  Ecology_2_A    10000 non-null  int64
# ...

# %%
train_2.to_csv('First_blood.csv')
